# %% [markdown]
# ASSIGNMENT 2
#
# NAME: RENU COURSE: B.Tech (ECE) ENROLMENT NO.: 05601022025

# %% [markdown]
# Q-1 Find sum of the first 10 natural numbers.

# %%
sum=0
for i in range(1,11):
   sum+=i
print(sum)
# Out:
# 55

# %% [markdown]
# Q-2 Find factorial of a number.

# %%
fact=1
n=int(input("Enter ur number here:"))

for i in range(1,n+1):
  fact=fact*i

print(f"Factorial of a given number is {fact}")
# Out:
# Enter ur number here:5
# Factorial of a given number is 120

# %% [markdown]
# Q-3 Print fibonacci series.

# %%
n=int(input("Enter how many terms you want"))
a=0
b=1

for i in range (n):
  print(a,end=" ")
  c=a+b
  a=b
  b=c
# Out:
# Enter how many terms you want7
# 0 1 1 2 3 5 8

# %% [markdown]
# Q-4 Find largest among 3 number.

# %%
a=int(input("Enter ur number:"))
b=int(input("Enter ur number:"))
c=int(input("Enter ur number:"))

if a>b and b>c:
  print("a is the largest number.")
elif b>a and a>c:
  print("b is the largest number.")
else:
  print("c is the largest number.")
# Out:
# Enter ur number:1
# Enter ur number:1
# Enter ur number:3
# c is the largest number.

# %% [markdown]
# Q-5 Create student result system:
# -input students details   -input marks    -calculate percentage     -display grade  -use(if-elif-else and loops and user input)

# %%
name=input("Enter student name:")
roll=int(input("Enter student roll no.:"))

marks=0
for i in range(1,6):
  a=int(input("enter ur subject marks:"))
  marks+=a

final_score = marks/5

print("-----REPORT CARD-----")
print(f"name of the student: {name}")
print(f"Roll no. of the student: {roll}")
print(f"Total marks : {marks}")
print(f"percentage of student: {final_score}")


if final_score>=90:
  print("Your grade is A+")
elif final_score>=80 and final_score<90:
  print("Your grade is A")
elif final_score>=70 and final_score<80:
  print("Your grade is =B+")
elif final_score>=60 and final_score<70:
  print("Your grade is B")
elif final_score>=50 and final_score<60:
  print("Your grade is C")
elif final_score>=40 and final_score<50:
  print("Your grade is D")
else:
  print("your grade is F")
  print("YOU ARE FAIL")
# Out:
# Enter student name:Amit
# Enter student roll no.:64
# enter ur subject marks:21
# enter ur subject marks:12
# enter ur subject marks:54
# enter ur subject marks:32
# enter ur subject marks:12
# -----REPORT CARD-----
# name of the student: Amit
# Roll no. of the student: 64
# Total marks : 131
# percentage of student: 26.2
# your grade is F
# YOU ARE FAIL
