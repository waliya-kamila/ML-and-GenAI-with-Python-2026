# %% [markdown]
# <a href="https://colab.research.google.com/github/waliya-kamila/ML-and-GenAI-with-Python-2026/blob/main/Assignment_2/waliya_150.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Sum of first 10 natural numbers
total = 0
for i in range(1, 11):
    total += i
print("Sum of first 10 natural numbers:", total)

# 2. Factorial of a number
num = int(input("Enter a number: "))
factorial = 1
for i in range(1, num + 1):
    factorial *= i
print("Factorial of", num, "is:", factorial)

# 3. Fibonacci Series
n = int(input("How many terms? "))
a, b = 0, 1
print("Fibonacci Series:", end=" ")
for i in range(n):
    print(a, end=" ")
    a, b = b, a + b

# 4. Largest among three numbers
print()
a = float(input("Enter number 1: "))
b = float(input("Enter number 2: "))
c = float(input("Enter number 3: "))
if a >= b and a >= c:
    print("Largest:", a)
elif b >= a and b >= c:
    print("Largest:", b)
else:
    print("Largest:", c)

# 5. Student Result System
name = input("Enter student name: ")
roll = input("Enter roll number: ")
m1 = float(input("Enter marks in Subject 1: "))
m2 = float(input("Enter marks in Subject 2: "))
m3 = float(input("Enter marks in Subject 3: "))
m4 = float(input("Enter marks in Subject 4: "))
m5 = float(input("Enter marks in Subject 5: "))
total = m1 + m2 + m3 + m4 + m5
percentage = (total / 500) * 100
if percentage >= 90:
    grade = "A+"
elif percentage >= 80:
    grade = "A"
elif percentage >= 70:
    grade = "B"
elif percentage >= 60:
    grade = "C"
elif percentage >= 40:
    grade = "D"
else:
    grade = "FAIL"
print("\n====== Student Result ======")
print("Name:", name)
print("Roll No:", roll)
print("Total Marks:", total, "/ 500")
print("Percentage:", percentage, "%")
print("Grade:", grade)
if percentage >= 40:
    print("Result: PASS")
else:
    print("Result: FAIL")
